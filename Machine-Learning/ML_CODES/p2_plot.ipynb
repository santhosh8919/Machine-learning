# %%
 import pandas as pd
 df=pd.read_csv("Data.csv")
 print(df)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
import matplotlib.pyplot as plt
df['Country'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
 df['Country'].value_counts().head(-1).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
#verical print
df['Salary'].value_counts().plot(kind="barh")
plt.xlabel("count")
plt.ylabel("salary")
plt.title("salary Distribution")
# Out:
# Text(0.5, 1.0, 'salary Distribution')

# %%
#count
df['Purchased'].value_counts()
# Out:
# Purchased
# No     5
# Yes    5
# Name: count, dtype: int64

# %%
type(df['Country'].value_counts())
# Out:
# pandas.core.series.Series

# %%
series=df['Salary'].value_counts()
series
# Out:
# Salary
# 72000.0    1
# 48000.0    1
# 54000.0    1
# 61000.0    1
# 58000.0    1
# 52000.0    1
# 79000.0    1
# 83000.0    1
# 67000.0    1
# Name: count, dtype: int64

# %%
  #adding  2 columns

df['Country'].value_counts() + df['Age'].value_counts()
# Out:
# 27.0      NaN
# 30.0      NaN
# 35.0      NaN
# 37.0      NaN
# 38.0      NaN
# 40.0      NaN
# 44.0      NaN
# 48.0      NaN
# 50.0      NaN
# France    NaN
# Germany   NaN
# Spain     NaN
# Name: count, dtype: float64

# %%
df['Age'].sort_values()
# Out:
# 1    27.0
# 2    30.0
# 5    35.0
# 9    37.0
# 3    38.0
# 4    40.0
# 0    44.0
# 7    48.0
# 8    50.0
# 6     NaN
# Name: Age, dtype: float64

# %%
df.drop_duplicates("Salary").shape[0]
# Out:
# 10

# %%
df.drop_duplicates(subset=['Salary','Age']).shape
# Out:
# (10, 4)
