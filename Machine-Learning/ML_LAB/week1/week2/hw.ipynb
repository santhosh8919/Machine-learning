# %%
import pandas as pd
df=pd.read_csv("car.csv")
df
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0    Acura          Integra                        16.919
# 1    Acura          TL                             39.384
# 2    Acura          CL                             14.114
# 3    Acura          RL                              8.588
# 4    Audi           A4                             20.397
# ..             ...                ...                 ...
# 152  Volvo          V40                             3.545
# 153  Volvo          S70                            15.245
# 154  Volvo          V70                            17.531
# 155  Volvo          C70                             3.493
# 156  Volvo          S80                            18.969
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0                 16.360    Passenger               21.50          1.8
# 1                 19.875    Passenger               28.40          3.2
# ...

# %%
#1. Read top five values
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands  4-year resale value  \
# 0  Acura          Integra                        16.919               16.360
# 1  Acura          TL                             39.384               19.875
# 2  Acura          CL                             14.114               18.225
# 3  Acura          RL                              8.588               29.725
# 4  Audi           A4                             20.397               22.255
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
# ...

# %%
print(df.dtypes)
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value    float64
# Vehicle type            object
# Price in thousands     float64
# Engine size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb weight            float64
# Fuel capacity          float64
# Fuel efficiency        float64
# Latest Launch           object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  121 non-null    float64
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   155 non-null    float64
#  6   Engine size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb weight          155 non-null    float64
#  12  Fuel capacity        156 non-null    float64
#  13  Fuel efficiency      154 non-null    float64
#  14  Latest Launch        157 non-null    object
# ...

# %%
#3. Print number of rows and columns
print("no of rows",df.shape[0])
print("no of columns",df.shape[1])
# Out:
# no of rows 157
# no of columns 15

# %%
print("All the rows",df.iloc[:])
print("All the columns",df.iloc[:, :])
# Out:
# All the rows       Manufacturer              Model  Sales in thousands  \
# 0    Acura          Integra                        16.919
# 1    Acura          TL                             39.384
# 2    Acura          CL                             14.114
# 3    Acura          RL                              8.588
# 4    Audi           A4                             20.397
# ..             ...                ...                 ...
# 152  Volvo          V40                             3.545
# 153  Volvo          S70                            15.245
# 154  Volvo          V70                            17.531
# 155  Volvo          C70                             3.493
# 156  Volvo          S80                            18.969
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0                 16.360    Passenger               21.50          1.8
# 1                 19.875    Passenger               28.40          3.2
# ...

# %%
#4. Drop duplicate rows_if any
df=df.drop_duplicates()
df
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0    Acura          Integra                        16.919
# 1    Acura          TL                             39.384
# 2    Acura          CL                             14.114
# 3    Acura          RL                              8.588
# 4    Audi           A4                             20.397
# ..             ...                ...                 ...
# 152  Volvo          V40                             3.545
# 153  Volvo          S70                            15.245
# 154  Volvo          V70                            17.531
# 155  Volvo          C70                             3.493
# 156  Volvo          S80                            18.969
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0                 16.360    Passenger               21.50          1.8
# 1                 19.875    Passenger               28.40          3.2
# ...

# %%
#5. Print number of rows and columns after droppingduplicates
print("no of rows",df.shape[0])
print(" no of cols",df.shape[1])
# Out:
# no of rows 157
#  no of cols 15

# %%
import pandas as pd
df = pd.read_csv('car.csv')
df = df.drop_duplicates()
print("\nShape after dropping duplicates:", df.shape)
# Out:
# Shape after dropping duplicates: (157, 15)

# %%
#6. Print summary statistics for numerical variables
df.describe()
# Out:
#        Sales in thousands  4-year resale value  Price in thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
#7. Print number of missing values in each column
print("\nMissing values in each column:")
miss=df.isna().sum()
print(miss)
# Out:
# Missing values in each column:
# Manufacturer            0
# Model                   0
# Sales in thousands      0
# 4-year resale value    36
# Vehicle type            0
# Price in thousands      2
# Engine size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb weight             2
# Fuel capacity           1
# Fuel efficiency         3
# Latest Launch           0
# dtype: int64

# %%
print(miss[miss>0])
# Out:
# 4-year resale value    36
# Price in thousands      2
# Engine size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb weight             2
# Fuel capacity           1
# Fuel efficiency         3
# dtype: int64

# %%
maxx=miss.max()
print("most missing values")
maxx
# Out:
# most missing values
# 36

# %%
#8. Drop the column with most missing values
import pandas as pd
df = pd.read_csv('car.csv')
column_most_missing = df.isna().sum().idxmax()  # Corrected by adding parentheses
df = df.drop(columns=[column_most_missing])
print("\nShape after dropping the column with most missing values:", df.shape)
# Out:
# Shape after dropping the column with most missing values: (157, 14)

# %%
#9. Drop the rows with categorical missing values

print("total missing\n")
m=df.isnull().sum()
print(m)
#geeting thr colums
col=df.select_dtypes(include=['object']).columns
df=df.dropna(subset=col)
print("drop values of categoricla wise",df.shape)
# Out:
# total missing
#
# Manufacturer          0
# Model                 0
# Sales in thousands    0
# Vehicle type          0
# Price in thousands    2
# Engine size           1
# Horsepower            1
# Wheelbase             1
# Width                 1
# Length                1
# Curb weight           2
# Fuel capacity         1
# Fuel efficiency       3
# Latest Launch         0
# dtype: int64
# drop values of categoricla wise (157, 14)

# %%
#10. Import the rows with numerical missing values

rows_with_missing_values = df[df.isnull().any(axis=1)]
rows_with_missing_values
# Out:
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 2    Acura          CL                             14.114    Passenger
# 15   Cadillac       Seville                        15.943    Passenger
# 33   Chrysler       Town & Country                 53.480          Car
# 38   Dodge          Intrepid                       88.028    Passenger
# 109  Oldsmobile     Intrigue                       38.554    Passenger
#
#      Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 2                   NaN          3.2       225.0      106.9   70.6   192.0
# 15               44.475          4.6       275.0      112.2   75.0   201.0
# 33                  NaN          NaN         NaN        NaN    NaN     NaN
# 38               22.505          2.7       202.0      113.0   74.7   203.7
# 109              24.150          3.5       215.0      109.0   73.6   195.9
#
#      Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# ...

# %%
#.11 Sort the data w.r.t price_find the details of the most sand the least expensive cars 
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands Vehicle type  \
# 0  Acura          Integra                        16.919    Passenger
# 1  Acura          TL                             39.384    Passenger
# 2  Acura          CL                             14.114    Passenger
# 3  Acura          RL                              8.588    Passenger
# 4  Audi           A4                             20.397    Passenger
#
#    Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# ...

# %%
#.11 Sort the data w.r.t price_find the details of the most sand the least expensive cars 
df_sort=df.sort_values(by="Price in thousands")
df_low=df_sort.iloc[0]
df_most=df_sort.iloc[-1]

print("least expensive",df_low)
print('most expensive',df_most)
# Out:
# least expensive Manufacturer              Chevrolet
# Model                 Metro
# Sales in thousands               21.855
# Vehicle type                  Passenger
# Price in thousands                9.235
# Engine size                         1.0
# Horsepower                         55.0
# Wheelbase                          93.1
# Width                              62.6
# Length                            149.4
# Curb weight                       1.895
# Fuel capacity                      10.3
# Fuel efficiency                    45.0
# Latest Launch                 13-Apr-14
# Name: 26, dtype: object
# most expensive Manufacturer              Chrysler
# Model                 Town & Country
# Sales in thousands                53.48
# Vehicle type                        Car
# Price in thousands                  NaN
# Engine size                         NaN
# Horsepower                          NaN
# Wheelbase                           NaN
# Width                               NaN
# ...

# %%
#12: Write a function to find min and max values of any column
def find_min_max(df, column_name):
    if column_name in df.columns:
        min_value = df[column_name].min()
        max_value = df[column_name].max()
        
        # Find rows with min and max values
        min_row = df[df[column_name] == min_value]
        max_row = df[df[column_name] == max_value]
        
        return min_value, max_value, min_row, max_row
    else:
        return None, f"Error: Column '{column_name}' not found in DataFrame."

# Example usage
column = "Horsepower"
min_val, max_val, min_row, max_row = find_min_max(df, column)
print(f"\nMin {column}:", min_val, "\n", min_row)
print(f"\nMax {column}:", max_val, "\n", max_row)
# Out:
# Min Horsepower: 55.0
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 26  Chevrolet      Metro                          21.855    Passenger
#
#     Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 26               9.235          1.0        55.0       93.1   62.6   149.4
#
#     Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 26        1.895           10.3             45.0     13-Apr-14
#
# Max Horsepower: 450.0
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 39  Dodge          Viper                           0.916    Passenger
#
#     Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 39              69.725          8.0       450.0       96.2   75.7   176.7
#
#     Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 39        3.375           19.0             16.0      8-Jul-15

# %%
#Q13: Call the above function for horsepower, length, fuel efficiency
for col in ["Horsepower", "Length", "Fuel efficiency"]:
    min_val, max_val, min_row, max_row = find_min_max(df, col)
    print(f"\n{col} - Min: {min_val} \n", min_row)
    print(f"\n{col} - Max: {max_val} \n", max_row)
# Out:
# Horsepower - Min: 55.0
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 26  Chevrolet      Metro                          21.855    Passenger
#
#     Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 26               9.235          1.0        55.0       93.1   62.6   149.4
#
#     Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 26        1.895           10.3             45.0     13-Apr-14
#
# Horsepower - Max: 450.0
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 39  Dodge          Viper                           0.916    Passenger
#
#     Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 39              69.725          8.0       450.0       96.2   75.7   176.7
#
#     Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 39        3.375           19.0             16.0      8-Jul-15
#
# Length - Min: 149.4
# ...

# %%
#: Plot histograms of continuous numerical variables

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset (replace 'your_data.csv' with the actual file)
# Plot histogram for price, new price, and extra price
plt.figure(figsize=(10, 6))
sns.histplot(df['Price in thousands'], color="blue", label="Price", kde=True, bins=20)
sns.histplot(df['Sales in thousands'], color="green", label="New Price", kde=True, bins=20)
sns.histplot(df['Horsepower'], color="red", label="Extra Price", kde=True, bins=20)

# Customize the plot
plt.xlabel("Price Values")
plt.ylabel("Frequency")
plt.title("Histogram of Prices")
plt.legend()
plt.show()

# %%
#: 15Plot the probability density distribution of "Length"

# %%
#Q16: Count by category – Group by manufacturer
manufacture_count=df.groupby('Manufacturer').size().reset_index(name="count")
manufacture_count
# Out:
#      Manufacturer  count
# 0   Acura              4
# 1   Audi               3
# 2   BMW                3
# 3   Buick              4
# 4   Cadillac           5
# 5   Chevrolet          9
# 6   Chrysler           7
# 7   Dodge             11
# 8   Ford              11
# 9   Honda              5
# 10  Hyundai            3
# 11  Infiniti           1
# 12  Jaguar             1
# 13  Jeep               3
# 14  Lexus              6
# 15  Lincoln            3
# 16  Mercedes-Benz      9
# 17  Mercury            6
# 18  Mitsubishi         7
# 19  Nissan             7
# 20  Oldsmobile         6
# 21  Plymouth           4
# 22  Pontiac            6
# 23  Porsche            3
# 24  Saab               2
# 25  Saturn             5
# 26  Subaru             2
# 27  Toyota             9
# 28  Volkswagen         6
# 29  Volvo              6

# %%
#Q17: Select all numerical variables
num=df.select_dtypes(include=['number']).columns
print("Numerical column::",num)
# Out:
# Numerical column:: Index(['Sales in thousands', 'Price in thousands', 'Engine size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel capacity',
#        'Fuel efficiency'],
#       dtype='object')

# %%
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands Vehicle type  \
# 0  Acura          Integra                        16.919    Passenger
# 1  Acura          TL                             39.384    Passenger
# 2  Acura          CL                             14.114    Passenger
# 3  Acura          RL                              8.588    Passenger
# 4  Audi           A4                             20.397    Passenger
#
#    Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# ...

# %%
#Q18: Print correlation coefficient between price and sales
correlation=df['Price in thousands'].corr(df['Sales in thousands'])
print(f"correlation between prices and sales is:{correlation}")
# Out:
# correlation between prices and sales is:-0.3047344541294122

# %%
#19 : Plot the correlation between price and sales using a scatterplot
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['Price in thousands'],y=df['Sales in thousands'])
plt.xlabel("Prices in thousands")
plt.ylabel("Sales in thousands")
plt.title("Prices vs Sales scatter plot")
plt.show()

# %%
#20: Create a pair plot
sns.pairplot(df)
plt.show()

# %%
#21 nad 22@: Boxplot of sales & numerical variables w.r.t manufacturer
sns.boxplot(x='Manufacturer',y='Sales in thousands',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
#23: Divide data into X (inputs) & y (output)
y=df['Sales in thousands']
x=df.drop(columns=['Sales in thousands'])
print("x shape:",x.shape)
print("y shape",y.shape)
# Out:
# x shape: (157, 13)
# y shape (157,)

# %%
#24 Encode categorical variables using Label Encoding
from sklearn.preprocessing import LabelEncoder

categorical_columns = x.select_dtypes(include=['object']).columns
label_encoders = {}

for col in categorical_columns:
    le = LabelEncoder()
    x[col] = le.fit_transform(x[col])
    label_encoders[col] = le

print(x.head())
# Out:
#    Manufacturer  Model  Vehicle type  Price in thousands  Engine size  \
# 0             0     79             1               21.50          1.8
# 1             0    143             1               28.40          3.2
# 2             0     25             1                 NaN          3.2
# 3             0    115             1               42.00          3.5
# 4             1      8             1               23.99          1.8
#
#    Horsepower  Wheelbase  Width  Length  Curb weight  Fuel capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# 1       225.0      108.1   70.3   192.9        3.517           17.2
# 2       225.0      106.9   70.6   192.0        3.470           17.2
# 3       210.0      114.6   71.4   196.6        3.850           18.0
# 4       150.0      102.6   68.2   178.0        2.998           16.4
#
#    Fuel efficiency  Latest Launch
# 0             28.0             42
# 1             25.0            112
# ...

# %%
#25 : Encode "Vehicle Type" using One-Hot Encoding
x = pd.get_dummies(x, columns=['Vehicle type'], prefix='Vehicle', drop_first=True)
print(x.head())
# Out:
#    Manufacturer  Model  Price in thousands  Engine size  Horsepower  \
# 0             0     79               21.50          1.8       140.0
# 1             0    143               28.40          3.2       225.0
# 2             0     25                 NaN          3.2       225.0
# 3             0    115               42.00          3.5       210.0
# 4             1      8               23.99          1.8       150.0
#
#    Wheelbase  Width  Length  Curb weight  Fuel capacity  Fuel efficiency  \
# 0      101.2   67.3   172.4        2.639           13.2             28.0
# 1      108.1   70.3   192.9        3.517           17.2             25.0
# 2      106.9   70.6   192.0        3.470           17.2             26.0
# 3      114.6   71.4   196.6        3.850           18.0             22.0
# 4      102.6   68.2   178.0        2.998           16.4             27.0
#
#    Latest Launch  Vehicle_1
# 0             42       True
# 1            112       True
# 2              0       True
# ...

# %%
# 26: Split data into train (70%) & test (10%)
from sklearn.model_selection import train_test_split

X_train, X_temp, y_train, y_temp = train_test_split(x, y, test_size=0.30, random_state=42)
X_test, _, y_test, _ = train_test_split(X_temp, y_temp, test_size=2/3, random_state=42)

print("Training set:", X_train.shape, y_train.shape)
print("Test set:", X_test.shape, y_test.shape)
# Out:
# Training set: (109, 13) (109,)
# Test set: (16, 13) (16,)

# %%
#27: Apply feature scaling on numerical 
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
X_standardized = scaler.fit_transform(x)

normalizer = MinMaxScaler()
X_normalized = normalizer.fit_transform(x)

print("Standardized Data:\n", X_standardized[:5])
print("\nNormalized Data:\n", X_normalized[:5])
# Out:
# Standardized Data:
#  [[-1.69422104  0.02962311 -0.41178878 -1.21088853 -0.81298837 -0.82543881
#   -1.11892896 -1.11613994 -1.17592298 -1.22616352  0.97354422 -0.6281665
#    0.59451516]
#  [-1.69422104  1.45380028  0.07055052  0.13358557  0.69094938  0.08045672
#   -0.24703626  0.41500948  0.22113294 -0.19402264  0.27076698  1.28417417
#    0.59451516]
#  [-1.69422104 -1.17202637         nan  0.13358557  0.69094938 -0.07709033
#   -0.15984699  0.34778828  0.14634748 -0.19402264  0.50502606 -1.77557089
#    0.59451516]
#  [-1.69422104  0.83072277  1.02124827  0.42168716  0.4255486   0.93383657
#    0.07265772  0.69136328  0.75099583  0.01240554 -0.43201025  0.79242942
#    0.59451516]
#  [-1.57750639 -1.55032344 -0.2377272  -1.21088853 -0.63605452 -0.64163392
#   -0.85736115 -0.69787473 -0.60468941 -0.40045081  0.73928514 -1.72093259
#    0.59451516]]
#
# Normalized Data:
#  [[0.         0.50967742 0.16082082 0.11428571 0.21518987 0.18655098
# ...
