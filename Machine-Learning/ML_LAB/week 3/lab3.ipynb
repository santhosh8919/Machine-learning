# %%
import pandas as pd
df=pd.read_csv("tvmarketing.csv")
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
X = df[['TV']]
y = df['Sales']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
print(df.shape)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (200, 2)
# (140, 1) (60, 1) (140,) (60,)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.xlabel("Tv")
plt.ylabel("sales")
plt.title("tv vs sales")
plt.show()

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
model = LinearRegression()
model.fit( X=x, y=y)
print(model.coef_, model.intercept_)
# Out:
# [0.         0.04753664] 7.032593549127694

# %%
y=7.011085360330938 + 0.0474615 * X

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,model.predict(X_train),color='red')

# %%
model.predict([[100,]])
# Out:
# c:\Users\Ramu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.76751664])

# %%
from sklearn.metrics import mean_squared_error
y_predict=model.predict(X_test)
print(mean_squared_error(y_test,y_predict))
# Out:
# 10.42990183083897

# %%
X_train
# Out:
#         TV
# 23   228.3
# 182   56.2
# 152  197.6
# 136   25.6
# 38    43.1
# ..     ...
# 169  284.3
# 195   38.2
# 76    27.5
# 116  139.2
# 175  276.9
#
# [140 rows x 1 columns]

# %%
import numpy as np
df.insert(0,'bias',1)

# %%
df
# Out:
#      bias     TV  Sales
# 0       1  230.1   22.1
# 1       1   44.5   10.4
# 2       1   17.2    9.3
# 3       1  151.5   18.5
# 4       1  180.8   12.9
# ..    ...    ...    ...
# 195     1   38.2    7.6
# 196     1   94.2    9.7
# 197     1  177.0   12.8
# 198     1  283.6   25.5
# 199     1  232.1   13.4
#
# [200 rows x 3 columns]

# %%
df2=pd.read_csv("tvmarketing.csv")
df2.insert(0,'bias',1)

# %%
df2
# Out:
#      bias     TV  Sales
# 0       1  230.1   22.1
# 1       1   44.5   10.4
# 2       1   17.2    9.3
# 3       1  151.5   18.5
# 4       1  180.8   12.9
# ..    ...    ...    ...
# 195     1   38.2    7.6
# 196     1   94.2    9.7
# 197     1  177.0   12.8
# 198     1  283.6   25.5
# 199     1  232.1   13.4
#
# [200 rows x 3 columns]

# %%
x=df2[['bias','TV']]
y=df2['Sales']

# %%
x
# Out:
#      bias     TV
# 0       1  230.1
# 1       1   44.5
# 2       1   17.2
# 3       1  151.5
# 4       1  180.8
# ..    ...    ...
# 195     1   38.2
# 196     1   94.2
# 197     1  177.0
# 198     1  283.6
# 199     1  232.1
#
# [200 rows x 2 columns]

# %%
# y_hat = theta_0 * 1 + theta_1 * x

# %%
x = np.array(x) 
y = np.array(y)

# %%
theta = np.linalg.inv(x.T@x)@x.T@y
print(theta)
# Out:
# 0    7.032594
# 1    0.047537
# dtype: float64
